# %%
import pandas as pd

# %%
# Importing the dataset
data = pd.read_csv('final.csv')

# %%
# removing duplicates from the dataset based on the 'id' column
data = data.drop_duplicates(subset='id', keep='first')

# %%
data
# Out:
#         id  age    female                        edu                emp  \
# 0        1   57  männlich   einen Realschulabschluss  nicht berufstätig
# 5        2   53  männlich   einen Hochschulabschluss        berufstätig
# 10       6   58  männlich   einen Hochschulabschluss        berufstätig
# 14       7   66  weiblich   einen Realschulabschluss  nicht berufstätig
# 18      11   68  weiblich  einen Hauptschulabschluss  nicht berufstätig
# ...    ...  ...       ...                        ...                ...
# 8084  2111   76  weiblich  einen Hauptschulabschluss  nicht berufstätig
# 8089  2113   77  weiblich  einen Hauptschulabschluss  nicht berufstätig
# 8093  2114   78  weiblich  einen Hauptschulabschluss  nicht berufstätig
# 8269   313   50  weiblich   einen Realschulabschluss        berufstätig
# 8986  1655   41  männlich  einen Hauptschulabschluss        berufstätig
#
#        hhincome             east                 religious      leftright  \
# 0     niedriges  Westdeutschland             sehr religiös  mittig rechts
# 5     mittleres  Westdeutschland       nicht sehr religiös   in der Mitte
# 10    mittleres  Westdeutschland  überhaupt nicht religiös   mittig links
# 14    mittleres  Westdeutschland  überhaupt nicht religiös   mittig links
# 18    mittleres  Westdeutschland  überhaupt nicht religiös   in der Mitte
# ...         ...              ...                       ...            ...
# 8084  mittleres   Ostdeutschland            etwas religiös   in der Mitte
# 8089  mittleres   Ostdeutschland            etwas religiös   in der Mitte
# 8093  mittleres   Ostdeutschland             sehr religiös   in der Mitte
# 8269  mittleres  Westdeutschland  überhaupt nicht religiös   in der Mitte
# 8986  mittleres   Ostdeutschland       nicht sehr religiös   in der Mitte
#
#                                    partyid  ... matched_new_1 resampled_1  \
# 0                   mit der Partei CDU/CSU  ...           NaN         NaN
# 5                       mit der Partei SPD  ...           NaN         NaN
# 10    mit der Partei Bündnis 90/Die Grünen  ...           NaN         NaN
# 14                      mit der Partei SPD  ...           NaN         NaN
# 18                      mit der Partei SPD  ...           NaN         NaN
# ...                                    ...  ...           ...         ...
# 8084                mit der Partei CDU/CSU  ...           NaN         NaN
# 8089                mit der Partei CDU/CSU  ...           NaN         NaN
# 8093                mit der Partei CDU/CSU  ...           NaN         NaN
# 8269                     mit keiner Partei  ...           NaN         1.0
# 8986                     mit keiner Partei  ...           NaN         1.0
#
#      completion_2 matched_2 check_manually_2  manipulated_2 matched_new_2  \
# 0             NaN       NaN              NaN            NaN           NaN
# 5             NaN       NaN              NaN            NaN           NaN
# 10            NaN       NaN              NaN            NaN           NaN
# 14            NaN       NaN              NaN            NaN           NaN
# 18            NaN       NaN              NaN            NaN           NaN
# ...           ...       ...              ...            ...           ...
# 8084          NaN       NaN              NaN            NaN           NaN
# 8089          NaN       NaN              NaN            NaN           NaN
# 8093          NaN       NaN              NaN            NaN           NaN
# 8269          NaN       NaN              NaN            NaN           NaN
# 8986          NaN       NaN              NaN            NaN           NaN
#
#       resampled_2 match_vote_outcome               vote_gpt
# 0             NaN              False          Nicht gewählt
# 5             NaN               True  Bündnis 90/Die Grünen
# 10            NaN               True  Bündnis 90/Die Grünen
# 14            NaN               True                    SPD
# 18            NaN              False                    SPD
# ...           ...                ...                    ...
# 8084          NaN               True                CDU/CSU
# 8089          NaN               True                CDU/CSU
# 8093          NaN               True                CDU/CSU
# 8269          NaN              False                CDU/CSU
# 8986          NaN              False                    AfD
#
# [1905 rows x 38 columns]

# %%
X = data.iloc[:, 0:14]
y = data['vote']

# %%
X
# Out:
#         id  age    female                        edu                emp  \
# 0        1   57  männlich   einen Realschulabschluss  nicht berufstätig
# 5        2   53  männlich   einen Hochschulabschluss        berufstätig
# 10       6   58  männlich   einen Hochschulabschluss        berufstätig
# 14       7   66  weiblich   einen Realschulabschluss  nicht berufstätig
# 18      11   68  weiblich  einen Hauptschulabschluss  nicht berufstätig
# ...    ...  ...       ...                        ...                ...
# 8084  2111   76  weiblich  einen Hauptschulabschluss  nicht berufstätig
# 8089  2113   77  weiblich  einen Hauptschulabschluss  nicht berufstätig
# 8093  2114   78  weiblich  einen Hauptschulabschluss  nicht berufstätig
# 8269   313   50  weiblich   einen Realschulabschluss        berufstätig
# 8986  1655   41  männlich  einen Hauptschulabschluss        berufstätig
#
#        hhincome             east                 religious      leftright  \
# 0     niedriges  Westdeutschland             sehr religiös  mittig rechts
# 5     mittleres  Westdeutschland       nicht sehr religiös   in der Mitte
# 10    mittleres  Westdeutschland  überhaupt nicht religiös   mittig links
# 14    mittleres  Westdeutschland  überhaupt nicht religiös   mittig links
# 18    mittleres  Westdeutschland  überhaupt nicht religiös   in der Mitte
# ...         ...              ...                       ...            ...
# 8084  mittleres   Ostdeutschland            etwas religiös   in der Mitte
# 8089  mittleres   Ostdeutschland            etwas religiös   in der Mitte
# 8093  mittleres   Ostdeutschland             sehr religiös   in der Mitte
# 8269  mittleres  Westdeutschland  überhaupt nicht religiös   in der Mitte
# 8986  mittleres   Ostdeutschland       nicht sehr religiös   in der Mitte
#
#                                    partyid   partyid_degree  \
# 0                   mit der Partei CDU/CSU           mäßig
# 5                       mit der Partei SPD  ziemlich stark
# 10    mit der Partei Bündnis 90/Die Grünen  ziemlich stark
# 14                      mit der Partei SPD  ziemlich stark
# 18                      mit der Partei SPD  ziemlich stark
# ...                                    ...              ...
# 8084                mit der Partei CDU/CSU           mäßig
# 8089                mit der Partei CDU/CSU           mäßig
# 8093                mit der Partei CDU/CSU  ziemlich stark
# 8269                     mit keiner Partei              NaN
# 8986                     mit keiner Partei              NaN
#
#                                                   party  \
# 0                          mäßig mit der Partei CDU/CSU
# 5                     ziemlich stark mit der Partei SPD
# 10    ziemlich stark mit der Partei Bündnis 90/Die G...
# 14                    ziemlich stark mit der Partei SPD
# 18                    ziemlich stark mit der Partei SPD
# ...                                                 ...
# 8084                       mäßig mit der Partei CDU/CSU
# 8089                       mäßig mit der Partei CDU/CSU
# 8093              ziemlich stark mit der Partei CDU/CSU
# 8269                                  mit keiner Partei
# 8986                                  mit keiner Partei
#
#                      inequality                          immigration
# 0     keine Maßnahmen ergreifen                          erleichtern
# 5           Maßnahmen ergreifen                          erleichtern
# 10          Maßnahmen ergreifen  weder erleichtern noch einschränken
# 14          Maßnahmen ergreifen                          erleichtern
# 18          Maßnahmen ergreifen  weder erleichtern noch einschränken
# ...                         ...                                  ...
# 8084        Maßnahmen ergreifen                         einschränken
# 8089        Maßnahmen ergreifen                         einschränken
# 8093        Maßnahmen ergreifen                         einschränken
# 8269        Maßnahmen ergreifen                         einschränken
# 8986        Maßnahmen ergreifen  weder erleichtern noch einschränken
#
# [1905 rows x 14 columns]

# %%
X.to_csv('X.csv', index=False)
y.to_csv('y.csv', index=False)

# %%
y
# Out:
# 0                     CDU/CSU
# 5       Bündnis 90/Die Grünen
# 10      Bündnis 90/Die Grünen
# 14                        SPD
# 18      Bündnis 90/Die Grünen
#                 ...
# 8084                  CDU/CSU
# 8089                  CDU/CSU
# 8093                  CDU/CSU
# 8269                      AfD
# 8986                  CDU/CSU
# Name: vote, Length: 1905, dtype: object
